# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T

import torchvision

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


seed = 123
np.random.seed(seed)

to_tensor = T.ToTensor()
to_pil = T.ToPILImage()

norm = T.Lambda(lambda x: 2 * x - 1)
denorm = T.Lambda(lambda x: (x + 1) / 2)

# %%
from dataset_generator import showImagesHorizontally
from train_dyn_p0_v2 import VQVAE, generate_random_image, generate_params
from train_orig_v2 import VQVAE as VQVAE2

# %%
import os
from PIL import Image

def construct_run_name(codebook_size, num_codebooks, region_size, p0):
    run_name = f'train_orig_cs{codebook_size}'
    if num_codebooks > 1:
        run_name += f'_nc{num_codebooks}'
    if p0 is not None:
        run_name += f'_{p0}'
    if region_size is not None:
        run_name += f'_{region_size}'
    return run_name


def read_samples(root, epoch=None):
    if epoch is None:
        files = sorted(os.listdir(root))
        path = os.path.join(root, files[-1])
        return Image.open(path).convert('RGB')
    file = f'epoch_{str(epoch).zfill(4)}.png'
    path = os.path.join(root, file)
    return Image.open(path).convert('RGB')


def read_snapshot(root):
    snapshot_path = os.path.join(root, 'snapshot.tar')
    snapshot = torch.load(snapshot_path, map_location='cpu')
    return snapshot


def plot_metrics(metrics, root=None):
    if root is not None:
        snapshot = read_snapshot(root)
        metrics = snapshot['metrics']
    fig, axes = plt.subplots(nrows=1, ncols=len(metrics), figsize=(20, 4))
    for (key, value), axis in zip(metrics.items(), axes):
        axis.plot(value)
        axis.grid()
        axis.set_xlabel('epoch')
        axis.set_ylabel(key)
        axis.set_title(f'{key} over epochs')

        
def build_model(snapshot):
    model_params = snapshot['model_params']
    state_dict = snapshot['model']
    if 'num_codebooks' not in model_params:
        model = VQVAE2(**model_params).eval()
    else:
        model = VQVAE(**model_params).eval()
    model.load_state_dict(state_dict)
    for p in model.parameters():
        p.requires_grad = False
    return model


def get_images(n):
    images = [generate_random_image(**generate_params) for _ in range(n)]
    images = [norm(to_tensor(image)) for image in images]
    images = torch.stack(images)
    return images

    
def infer_model(model, images):
    z = model.encoder(images)
    
#     shape = z.size(0), model.quantizer.num_codebooks, model.quantizer.n_embed, z.size(-2), z.size(-1)
    
    logits = model.quantizer.proj(z).view(z.size(0), -1, model.quantizer.n_embed, z.size(-2), z.size(-1))
    codes = F.gumbel_softmax(logits, tau=1, hard=True, dim=-3)
    
    soft_one_hot = codes.clone().view(z.size(0), -1, z.size(-2), z.size(-1))
    z_q = torch.einsum('b n h w, n d -> b d h w', soft_one_hot, model.quantizer.embed.weight)
    images_recon = model.decoder(z_q)
    
    n_selected = torch.sum(codes.argmax(dim=-3) != 0, dim=1)
    
    return images_recon, codes, n_selected


def create_grid(images, images_recon):
    grid = torch.cat([images, images_recon], dim=0)
    grid = torchvision.utils.make_grid(grid, nrow=images.size(0))
    grid = to_pil(denorm(grid))
    return grid

# %% [markdown]
# **Посмотрим на результаты обучения модели на отложенных картинках**

# %%
codebook_size = 32
num_codebooks = 8

# region_size = None
region_size = '16x16'

# p0 = None
p0 = 'p0'
# p0 = 'p08'

epoch = None
# epoch = 500

run_name = construct_run_name(codebook_size, num_codebooks, region_size, p0)
print(run_name)

samples_root = 'samples'
samples_run_root = os.path.join(samples_root, run_name)

samples = read_samples(samples_run_root, epoch=epoch)
samples
# Out:
# train_orig_cs32_nc8_p0_16x16
# <PIL.Image.Image image mode=RGB size=1292x518>

# %% [markdown]
# **Загрузим модель, сгенерируем картинки, прогоним модель и посмотрим результат реконструкции**

# %%
samples = read_samples('samples/train_orig_cs4_nc16_p0_16x16/', epoch=None)
samples
# Out:
# <PIL.Image.Image image mode=RGB size=1292x518>

# %%
snapshots_root = 'snapshots'
snapshots_run_root = os.path.join(snapshots_root, run_name)
snapshot = read_snapshot(snapshots_run_root)
model = build_model(snapshot)

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 17937859

# %% [markdown]
# number of parameters
#
# - cs128: 3 081 347
# - cs64: 3 060 803
# - cs4_nc16: 17 937 859

# %%
from train_dyn_p0_v2 import DeepMindEncoder, DeepMindDecoder, GumbelQuantize

class VQVAE_MOD(nn.Module):

    def __init__(self, input_channels=3, n_hid=64, n_downsamples=3, n_bottlenecks=2,
                       codebook_size=16, code_size=32, num_codebooks=4, target_density=0.1):
        super().__init__()
        self.encoder = DeepMindEncoder(input_channels=input_channels, n_hid=n_hid,
                                       n_downsamples=n_downsamples, n_bottlenecks=n_bottlenecks)
        self.decoder = DeepMindDecoder(output_channels=input_channels, n_init=code_size, n_hid=n_hid,
                                       n_upsamples=n_downsamples, n_bottlenecks=n_bottlenecks)
        self.quantizer = GumbelQuantize(self.encoder.output_channels, codebook_size, code_size, num_codebooks, target_density)


    def forward(self, x, tau=1):
        z = self.encoder(x)
        z_q, latent_loss, kl_p0 = self.quantizer(z, tau=tau)
        x_hat = self.decoder(z_q)
        return x_hat, latent_loss, kl_p0

# %%
snapshot['model_params']
# Out:
# {'input_channels': 3,
#  'n_hid': 64,
#  'n_downsamples': 4,
#  'n_bottlenecks': 4,
#  'code_size': 64,
#  'codebook_size': 4,
#  'num_codebooks': 16,
#  'target_density': 0.1}

# %%
params = snapshot['model_params'].copy()
for key, value in params.items():
    print(key, value)
params['n_hid'] = 28
params['n_bottlenecks'] = 4
print(f'\nchange n_hid = 32 and n_bottlenecks = 3')
print(params)
print(f'Number of parameters:', sum(p.numel() for p in VQVAE_MOD(**params).parameters()))
# Out:
# input_channels 3
# n_hid 64
# n_downsamples 4
# n_bottlenecks 4
# code_size 64
# codebook_size 4
# num_codebooks 16
# target_density 0.1
#
# change n_hid = 32 and n_bottlenecks = 3
# {'input_channels': 3, 'n_hid': 28, 'n_downsamples': 4, 'n_bottlenecks': 4, 'code_size': 64, 'codebook_size': 4, 'num_codebooks': 16, 'target_density': 0.1}
# Number of parameters: 2723755

# %%
2975195 / 3060803  # cs64_nc16 / cs64
# Out:
# 0.9720308690235863

# %%
from train_orig_v2 import VQVAE as VQVAE_ORIG
from train_dyn_p0_v2 import VQVAE as VQVAE_DYN_BUG
from train_dyn_p0_v2_honest import VQVAE as VQVAE_DYN

# %%
from pprint import pprint

# %%
path = 'snapshots/baselines_with_big_enc_dec/train_orig_cs128/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model_params = snapshot['model_params'].copy()
# model_params['code_size'] = 1024
# model_params['n_hid'] = 128
# model_params['n_bottlenecks'] = 5
model = VQVAE_ORIG(**model_params)
model.load_state_dict(snapshot['model'])
pprint(model_params)
sum(p.numel() for p in model.parameters())
# Out:
# {'code_size': 1024,
#  'codebook_size': 128,
#  'input_channels': 3,
#  'n_bottlenecks': 5,
#  'n_downsamples': 3,
#  'n_hid': 128}
# 19092099

# %%
17937859 / 18993731
# Out:
# 0.9444094475171835

# %%
path = 'snapshots/train_orig_cs64/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_ORIG(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
pprint(snapshot['model_params'])
sum(p.numel() for p in model.parameters())
# Out:
# {'code_size': 64,
#  'codebook_size': 64,
#  'input_channels': 3,
#  'n_bottlenecks': 3,
#  'n_downsamples': 3,
#  'n_hid': 64}
# 3060803

# %%
path = 'snapshots/train_orig_cs4_nc16_p0_16x16/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_DYN_BUG(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
sum(p.numel() for p in model.parameters())
# Out:
# 17937859

# %%
path = 'snapshots/train_orig_cs4_nc16_p0_16x16_honest/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_DYN(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
sum(p.numel() for p in model.parameters())
# Out:
# 2913755

# %%
2913755 / 3060803
# Out:
# 0.9519577052165723

# %%
path = 'snapshots/train_orig_cs8_nc16_p0_16x16_honest/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
# model = VQVAE_DYN(**snapshot['model_params'])
# model.load_state_dict(snapshot['model'])
# sum(p.numel() for p in model.parameters())
# Out:
# max_n_texts 2
# max_n_texts 2

# %%
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
epoch_recon_loss = [
    np.mean(recon_loss[i: i + 64])
    for i in range(0, len(recon_loss), 64)
]
plt.plot(epoch_recon_loss[800:]);
# plt.plot(recon_loss[50_000:]);

# %%
path = 'snapshots/train_orig_cs128/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_ORIG(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
pprint(snapshot['model_params'])
sum(p.numel() for p in model.parameters())
# Out:
# {'code_size': 64,
#  'codebook_size': 128,
#  'input_channels': 3,
#  'n_bottlenecks': 3,
#  'n_downsamples': 3,
#  'n_hid': 64}
# 3081347

# %%
path = 'snapshots/train_orig_cs8_nc16_p0_16x16/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_DYN_BUG(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
sum(p.numel() for p in model.parameters())
# Out:
# 18036227

# %%
18036227 / 3081347
# Out:
# 5.853357963254382

# %%
path = 'snapshots/train_orig_cs8_nc16_p0_16x16_honest/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
model = VQVAE_DYN(**snapshot['model_params'])
model.load_state_dict(snapshot['model'])
sum(p.numel() for p in model.parameters())
# Out:
# 2932251

# %%
2932251 / 3081347
# Out:
# 0.9516133690882591

# %%
18036227 / 19092099
# Out:
# 0.9446958660752807

# %%
path = 'snapshots/train_orig_cs4_nc16_p0_16x16_honest/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
plt.plot(epoch_recon_loss[500:], label='honest')


path = 'snapshots/train_orig_cs64/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
plt.plot(epoch_recon_loss[500:], label='baseline')

plt.ylabel('recon_loss')
plt.xlabel('epoch')
plt.title('cs64 and cs4_nc16')

plt.legend()
plt.show()

# %%
path = 'snapshots/train_orig_cs8_nc16_p0_16x16_honest/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
plt.plot(epoch_recon_loss[500:], label='honest')


path = 'snapshots/train_orig_cs128/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
plt.plot(epoch_recon_loss[500:], label='baseline')

plt.ylabel('recon_loss')
plt.xlabel('epoch')
plt.title('cs128 and cs8_nc16')

plt.legend()
plt.show()

# %%
path = 'snapshots/train_orig_cs4_nc16_p0_16x16/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
plt.plot(recon_loss[500:500+75_000], label='cs4_nc16')
# epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
# plt.plot(epoch_recon_loss[500:], label='honest')
print(recon_loss[500: 500 + 75_000][-1])
print(recon_loss[-1])
print(len(recon_loss))


path = 'snapshots/baselines_with_big_enc_dec/train_orig_cs64/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
plt.plot(recon_loss[500:500+75_000], label='baseline')
# epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
# plt.plot(epoch_recon_loss[500:], label='baseline')
print(recon_loss[500: 500 + 75_000][-1])

plt.ylabel('recon_loss')
plt.xlabel('epoch')
plt.title('cs64 and cs4_nc16')

plt.legend()
plt.show()
# Out:
# 0.0010424675419926643
# 0.00043971469858661294
# 176192
# 0.0006419229321181774

# %%
path = 'snapshots/train_orig_cs8_nc16_p0_16x16/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
plt.plot(recon_loss[500:500+75_000], label='cs4_nc16')
print(recon_loss[500: 500 + 75_000][-1])
print(recon_loss[-1])
print(len(recon_loss))
# epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
# plt.plot(epoch_recon_loss[500:], label='honest')


path = 'snapshots/baselines_with_big_enc_dec/train_orig_cs128/snapshot.tar'
snapshot = torch.load(path, map_location='cpu')
metrics = snapshot['metrics']
recon_loss = metrics['recon_loss']
plt.plot(recon_loss[500:500+75_000], label='baseline')
print(recon_loss[500: 500 + 75_000][-1])

# epoch_recon_loss = [np.mean(recon_loss[i: i + 64]) for i in range(0, len(recon_loss), 64)]
# plt.plot(epoch_recon_loss[500:], label='baseline')

plt.ylabel('recon_loss')
plt.xlabel('epoch')
plt.title('cs128 and cs8_nc16')

plt.legend()
plt.show()
# Out:
# 0.0007662046700716019
# 0.0004553842300083488
# 136512
# 0.0005392375751398504

# %%
# plot_metrics(None, root=snapshots_run_root)

# %%
# plot_metrics(None, root=snapshots_run_root)

# %%
# metrics_cs64_nc16 = snapshot['metrics']
# loss_cs64_nc16 = metrics_cs64_nc16['recon_loss']
# plt.plot(loss_cs64_nc16[10_000:]);

# %%
# codebook_size = 128
# num_codebooks = 1

# region_size = None
# # region_size = '16x16'

# p0 = None
# # p0 = 'p0'
# # p0 = 'p08'

# epoch = None
# # epoch = 500

# run_name = construct_run_name(codebook_size, num_codebooks, region_size, p0)

# snapshots_root = 'snapshots'
# snapshots_run_root = os.path.join(snapshots_root, run_name)
# snapshot = read_snapshot(snapshots_run_root)

# metrics_cs128 = snapshot['metrics']
# loss_cs128 = metrics_cs128['recon_loss']
# plt.plot(loss_cs128[10_000:]);

# %%
# plt.plot(loss_cs128[10_000:]);
# plt.plot(loss_cs64_nc16[10_000:]);

# %%
n_images = 5

model = build_model(snapshot)
images = get_images(n_images)
images_recon, codes, n_selected = infer_model(model, images)
create_grid(images, images_recon)
# Out:
# <PIL.Image.Image image mode=RGB size=1292x518>

# %%
showImagesHorizontally(n_selected, figsize=(20, 20))

# %%
i = 4
j = i + 1
showImagesHorizontally(n_selected[i: j], figsize=(8, 8))

# %% [markdown]
# **Картинка сверху - количество выбранных моделью ненулевых кодов в каждом регионе**
#
# **Посмотрим, сколько должно было быть кодов в регионе, сколько получилось. То же самое с длиной последовательности**

# %%
print('Mean number of selected codes per region')
print('actual:', torch.mean(n_selected.float(), dim=(1, 2)).mean().item())
print('expected:', 0.1 * num_codebooks)

print('\nLength of sequence')
print('actual:', torch.mean(n_selected.float().sum(dim=(1, 2))).item())
print('expected:', 0.1 * num_codebooks * n_selected.size(-2) * n_selected.size(-1))
print('No dyn. density:', 1024)
# Out:
# Mean number of selected codes per region
# actual: 3.9140625
# expected: 4.0
#
# Length of sequence
# actual: 1002.0
# expected: 1024.0
# No dyn. density: 1024
